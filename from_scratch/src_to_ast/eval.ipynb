# %%
# uncomment to install the required dependencies
# ! pip install -U torch datasets transformers tokenizers huggingface_hub pycommremover tqdm

# %%
# load the dataset

import datasets
from datasets import load_dataset

dataset = load_dataset('mrochk/src_ast_cfg')

print(dataset)
print(dataset['train'][0]['src'])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['src', 'cfg', 'ast'],
#         num_rows: 278620
#     })
#     validation: Dataset({
#         features: ['src', 'cfg', 'ast'],
#         num_rows: 15566
#     })
#     test: Dataset({
#         features: ['src', 'cfg', 'ast'],
#         num_rows: 15169
#     })
# })
# def findArgs(args, prefixes):
# 		"""
# 		Extracts the list of arguments that start with any of the specified prefix values
# 		"""
# 		return list([
# 			arg for arg in args
# 			if len([p for p in prefixes if arg.lower().startswith(p.lower())]) > 0
# 		])

# %%
# remove the comments from the functions and set labels to 0

from pycommremover import remove_comments

def f(sample:dict):
    """
    Remove the comments and set every label to 0.
    """
    sample['src'] = remove_comments(sample['src'])
    sample['label'] = 0
    return sample

train = dataset['train'].map(f)
test = dataset['test'].map(f)
validation = dataset['validation'].map(f)

print(train[0]['src'])
# Out:
# Map:   0%|          | 0/278620 [00:00<?, ? examples/s]
# Map:   0%|          | 0/15169 [00:00<?, ? examples/s]
# Map:   0%|          | 0/15566 [00:00<?, ? examples/s]
# def findArgs(args, prefixes):
#
# 		return list([
# 			arg for arg in args
# 			if len([p for p in prefixes if arg.lower().startswith(p.lower())]) > 0
# 		])

# %%
# now, we want to shuffle the dataset by exchanging
# ASTs randomly between samples: if we performed
# an exchange, we set the label to 1, otherwise 0

import torch
from tqdm import tqdm

def shuffle(dataset, percentage:float=0.5):
    """
    Shuffle dataset by exchanging ASTs.
    """
    asts   = dataset.data['ast'].to_pylist()
    srcs   = dataset.data['src'].to_pylist()
    labels = dataset.data['label'].to_pylist()

    # when we replace an ast we include the correct one
    # to be able to analyze the model's errors later
    asts_correct = ['' for _ in asts]

    # we exchange each ast at most once
    exchanged    = [False for _ in asts]

    length = len(dataset)

    # number of swaps to perform to shuffle the required percentage
    n_swaps = int(length * percentage) // 2

    print(f'Dataset length: {length}.')
    print(f'nPairs to swap: {n_swaps}...')

    n_swapped = 0

    for _ in range(n_swaps):
        # select 2 random rows that have not been exchanged before
        while True:
            
            row1 = torch.randint(low=0, high=length, size=(1,))
            row2 = torch.randint(low=0, high=length, size=(1,))
            
            condition = (not exchanged[row1]) and (not(exchanged[row2]))

            if condition: break
            
        if row1 == row2: continue # rows must be different

        ast1, ast2 = asts[row1], asts[row2]

        if ast1 == ast2: continue # asts must be different
            
        asts_correct[row1], asts_correct[row2] = ast1, ast2

        # performin the exchange
        asts[row1], asts[row2] = ast2, ast1

        # since we modified these rows we set their labels to 1
        labels[row1] = labels[row2] = 1

        # same for the list tracking the exchanged samples
        exchanged[row1] = exchanged[row2] = True

        n_swapped += 1

    print(f'nPairs swapped: {n_swapped}.')

    # building the new dataset
    new_dataset = [{'src':srcs[i], 'ast': asts[i], 'ast_correct': asts_correct[i], 'label':labels[i]} for i in range(length)]

    # converting it to a proper HuggingFace dataset and returning it
    return datasets.Dataset.from_list(new_dataset)

# %%
train = shuffle(train, .5); print()
test = shuffle(test, .5); print()
validation = shuffle(validation, .5)
# Out:
# Dataset length: 278620.
# nPairs to swap: 69655...
# nPairs swapped: 69655.
#
# Dataset length: 15169.
# nPairs to swap: 3792...
# nPairs swapped: 3792.
#
# Dataset length: 15566.
# nPairs to swap: 3891...
# nPairs swapped: 3891.

# %%
from transformers import AutoTokenizer
from tokenizers import Tokenizer

tokenizer_src = AutoTokenizer.from_pretrained(
    'huggingface/CodeBERTa-small-v1', 
    model_max_length=None, 
    force_download=True,
)

tokenizer_ast = Tokenizer.from_file(
    '/kaggle/input/tokenizer-ast-5000/tokenizer_ast_5000.json'
)

src = train[0]['src']
ast = train[0]['ast']

tokenizer_src_vocabsize = len(tokenizer_src.get_vocab())
tokenizer_ast_vocabsize = tokenizer_ast.get_vocab_size()
# Out:
# tokenizer_config.json:   0%|          | 0.00/19.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/19.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/994k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/483k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/19.0 [00:00<?, ?B/s]

# %%
seq_len_src = 550
seq_len_ast = 50

# %%
# we can now create the pytorch datasets

from torch.utils.data import Dataset, DataLoader

class SRC_AST_Dataset(Dataset):
    def __init__(
        self, 
        split, # the huggingface dataset split
        tokenizer_src=tokenizer_src,
        tokenizer_ast=tokenizer_ast,
        seq_len_src=seq_len_src,
        seq_len_ast=seq_len_ast,
    ):
        
        self.dataset = split

        self.seq_len_src = seq_len_src
        self.seq_len_ast = seq_len_ast

        self.tokenizer_src = tokenizer_src
        self.tokenizer_ast = tokenizer_ast

        self.cls_token_src = tokenizer_src.cls_token_id
        self.cls_token_ast = tokenizer_ast.token_to_id('[CLS]')

        self.pad_token_src = tokenizer_src.pad_token_id
        self.pad_token_ast = tokenizer_ast.token_to_id('[PAD]')

    def __len__(self): return len(self.dataset)

    def __getitem__(self, index):
        row = self.dataset[index]
        src, ast, label = row['src'], row['ast'], row['label']

        input_tokens_src = [self.cls_token_src] + self.tokenizer_src.encode(src)
        input_tokens_ast = [self.cls_token_ast] + self.tokenizer_ast.encode(ast).ids

        n_pad_tokens_src = self.seq_len_src - len(input_tokens_src)
        n_pad_tokens_ast = self.seq_len_ast - len(input_tokens_ast)
        
        if n_pad_tokens_src >= 0: # we add padding tokens if needed
            input_tokens_src = input_tokens_src + ([self.pad_token_src] * n_pad_tokens_src)
        else: # the sequence is larger than the max seq length
            input_tokens_src = input_tokens_src[:self.seq_len_src] # we crop it

        if n_pad_tokens_ast >= 0: # we add padding tokens if needed
            input_tokens_ast = input_tokens_ast + ([self.pad_token_ast] * n_pad_tokens_ast)
        else: # the sequence is larger than the max seq length
            input_tokens_ast = input_tokens_ast[:self.seq_len_ast] # we crop it

        return {
            'input_tokens_src': torch.tensor(input_tokens_src, dtype=torch.int64),
            'input_tokens_ast': torch.tensor(input_tokens_ast, dtype=torch.int64),
            'label': torch.tensor(label, dtype=torch.float).unsqueeze(-1)
        }

# %%
# instantiating the datasets

ds_train = SRC_AST_Dataset(train, tokenizer_src, tokenizer_ast)
ds_test = SRC_AST_Dataset(test, tokenizer_src, tokenizer_ast)
ds_validation = SRC_AST_Dataset(validation, tokenizer_src, tokenizer_ast)

print(ds_train[0]['input_tokens_src'].shape)
print(ds_train[0]['input_tokens_ast'].shape)
print(ds_train[0]['label'].shape)
# Out:
# torch.Size([550])
# torch.Size([50])
# torch.Size([1])

# %%
# the positional encoding as in Attention Is All You Need

from torch import nn
import math

class PositionalEncoding(nn.Module):
    def __init__(self, d_model:int, seq_len:int, dropout:float=0.1):
        super().__init__()

        self.dropout = nn.Dropout(dropout)

        position = torch.arange(seq_len, dtype=torch.float).unsqueeze(1)

        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10_000.0) / d_model))

        pe = torch.zeros(seq_len, d_model)

        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)

        pe = pe.unsqueeze(0)

        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + (self.pe[:, :x.shape[1], :]).requires_grad_(False)
        return self.dropout(x)

# creating the transformer encoder module

class Encoder(nn.Module):
    def __init__(
        self,
        vocab_size:int,  # tokenizer vocab size
        seq_len:int,     # sequence length in our batch
        pad_token:int,   # token used for padding
        nlayers:int=8,   # number of layers
        nheads:int=8,    # number of attention heads
        d_model:int=512, # embedding size for each token & also dimension of output
        d_ff:int=2048,   # ffn hidden layer size
        ):

        super().__init__()

        self.pad_token = pad_token

        self.input_embedding = nn.Embedding(
            num_embeddings=vocab_size,
            embedding_dim=d_model,
        )

        self.positional_encoding = PositionalEncoding(
            d_model=d_model,
            seq_len=seq_len,
        )

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nheads,
            dim_feedforward=d_ff,
            batch_first=True,
        )

        self.encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=nlayers
        )

    def forward(self, x):

        x = self.input_embedding(x)

        x = self.positional_encoding(x)

        x = self.encoder(x)[:, 0]

        return x
    
# now we define the complete architecture of our model

class SrcAstClassifier(nn.Module):
    def __init__(
        self,
        vocab_size_src:int,  # vocab size of src tokenizer
        vocab_size_ast:int,  # vocab size of cfg tokenizer
        
        seq_len_src:int,     # batch sequence length for src
        seq_len_ast:int,     # batch sequence length for cfg
        
        pad_token_src:int,   # token used to pad src
        pad_token_ast:int,   # token used to pad cfg
        
        d_model_src:int=512, # embedding size for each tokens in ast encoder
        d_model_ast:int=512, # embedding size for each tokens in src encoder
        
        nlayers_src:int=8,
        nlayers_ast:int=8,
        
        nheads_src:int=8,
        nheads_ast:int=8,
        
        d_ff:int=2048,       # ffn hidden layer size
        
        d_ff_enc:int=2048,   # encoders ffn hidden layer size
        ):

        super().__init__()

        # the encoder used to encode the function source code
        self.encoder_src = Encoder(
            vocab_size=vocab_size_src,
            seq_len=seq_len_src,
            pad_token=pad_token_src,
            d_model=d_model_src,
            d_ff=d_ff_enc,
            nlayers=nlayers_src,
            nheads=nheads_src,
        )

        # the encoder used to encode the function cfg
        self.encoder_ast = Encoder(
            vocab_size=vocab_size_ast,
            seq_len=seq_len_ast,
            pad_token=pad_token_ast,
            d_model=d_model_ast,
            d_ff=d_ff_enc,
            nlayers=nlayers_ast,
            nheads=nheads_ast,
        )
        
        # feedforward layer
        self.ffn = nn.Sequential(
            nn.Linear(d_model_ast + d_model_src, d_ff),
            nn.ReLU(),
            nn.Linear(d_ff, 1)
        )

        # output
        self.logistic = nn.Sigmoid()

    def forward(self, src, ast):
        
        out_src = self.encoder_src(src)
        out_ast = self.encoder_ast(ast)

        cat = torch.cat([out_src, out_ast], dim=-1)

        ffn = self.ffn(cat)

        out = self.logistic(ffn)

        return out

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using {device}.')
# Out:
# Using cuda.

# %%
model = torch.load('/kaggle/input/src_to_ast/pytorch/_/1/src_to_ast_3 (1).pt').to(device)

# %%
# getting predictions

def predictions(model:nn.Module, dataset:Dataset, batch_size:int=128):
    model.eval()

    labels, preds = [], []
    batchs = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    for batch in tqdm(batchs):

        ast    = batch['input_tokens_ast'].to(device)
        src    = batch['input_tokens_src'].to(device)
        labels += batch['label'].to(device).int().squeeze(1).tolist()
        preds  += [_.item() for _ in (model(src, ast).squeeze(1) > 0.5).int()]

    return preds, labels

preds_val,  labels_val  = predictions(model, ds_validation)
preds_test, labels_test = predictions(model, ds_test)
# Out:
# 100%|██████████| 122/122 [00:51<00:00,  2.39it/s]
# 100%|██████████| 119/119 [00:49<00:00,  2.40it/s]

# %%
from sklearn.metrics import classification_report

print('On test set:')
print(classification_report(labels_test, preds_test))

print('On validation set:')
print(classification_report(labels_val, preds_val), '\n____')
# Out:
# On test set:
#               precision    recall  f1-score   support
#
#            0       0.82      0.95      0.88      7585
#            1       0.94      0.80      0.86      7584
#
#     accuracy                           0.87     15169
#    macro avg       0.88      0.87      0.87     15169
# weighted avg       0.88      0.87      0.87     15169
#
# On validation set:
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88      7784
#            1       0.93      0.80      0.86      7782
#
#     accuracy                           0.87     15566
#    macro avg       0.88      0.87      0.87     15566
# weighted avg       0.88      0.87      0.87     15566
#
# ____

# %%
def get_errors(model, dataset, raw_dataset):
    model.eval()

    errors = []
    batchs = DataLoader(
        dataset, 
        batch_size=1, # must be 1
        shuffle=False
    )

    idx = 0
    for batch in tqdm(batchs):

        ast    = batch['input_tokens_ast'].to(device)
        src    = batch['input_tokens_src'].to(device)
        labels = batch['label'].to(device).int().squeeze(1).tolist()

        prediction = [_.item() for _ in (model(src, ast).squeeze(1) > 0.5).int()]
        
        if prediction != labels:
        
            row = raw_dataset[idx]
        
            errors.append({
                'src': row['src'],
                'src_tokenization': tokenizer_src.convert_ids_to_tokens(tokenizer_src.encode(row["src"])),
                'ast': row['ast'],
                'ast_tokenization': tokenizer_ast.encode(row["ast"]).tokens,
                'ast_correct': row['ast_correct'],
                'prediction': prediction[0],
            })
            
        idx += 1

    return errors

errors = get_errors(model, ds_validation, validation)
# Out:
# 100%|██████████| 15566/15566 [02:51<00:00, 90.89it/s]

# %%
errors_related = errors_nonrelated = 0

for _ in errors:
    if _['prediction'] == 0: errors_related += 1
    else: errors_nonrelated += 1
        
print(f'Model predicted RELATED     wrong {errors_related} times.')
print(f'Model predicted NON-RELATED wrong {errors_nonrelated} times.')
# Out:
# Model predicted RELATED     wrong 1547 times.
# Model predicted NON-RELATED wrong 461 times.

# %%
def str_error(error):
    prediction = error['prediction']
    label      = 'RELATED' if prediction == 1 else 'NOT RELATED'
    prediction = 'RELATED' if prediction == 0 else 'NOT RELATED'
    
    s = ''
    
    s += f'For label {label}, model predicted {prediction}.\n\n'
    
    s += (f'Source:_____\n{error["src"]}\n\n')
    
    s += (f'Source Tokenization:_____\n{str(error["src_tokenization"])}\n\n')
    
    s += (f'AST:_____\n{error["ast"]}\n\n')
    
    s += (f'AST Tokenization:_____\n{error["ast_tokenization"]}\n\n')
    
    if correct := error['ast_correct'] != '': 
        s += (f'Correct AST:_____\n{error["ast_correct"]}')
        
    return s

# %%
from random import randint

with open('errors.txt', 'w') as out:
    for i in range(50):
        idx = randint(0, len(errors))
        e = str_error(errors[idx])
        print(e)
        out.write(e + '\n===========================================\n')
# Out:
# For label RELATED, model predicted NOT RELATED.
#
# Source:_____
# def needs_initrole(self, stop_on_error=False):
#
#
#         ret = False
#
#         target_host_present = self.is_present()
#
#         if not target_host_present:
#             default_host_present = self.is_present(self.env.default_hostname)
#             if default_host_present:
#                 if self.verbose:
#                     print('Target host missing and default host present so host init required.')
#                 ret = True
#             else:
#                 if self.verbose:
#                     print('Target host missing but default host also missing, '
#                         'so no host init required.')
#
#
#
#
#         else:
#             if self.verbose:
#                 print('Target host is present so no host init required.')
#
#         return ret
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġneeds', '_', 'init', 'role', '(', 'self', ',', 'Ġstop', '_', 'on', '_', 'error', '=', 'False', '):', 'Ċ', 'ĠĠĠĠĠĠĠĠĊ', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġret', 'Ġ=', 'ĠFalse', 'Ċ', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġtarget', '_', 'host', '_', 'present', 'Ġ=', 'Ġself', '.', 'is', '_', 'present', '()', 'Ċ', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġif', 'Ġnot', 'Ġtarget', '_', 'host', '_', 'present', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġdefault', '_', 'host', '_', 'present', 'Ġ=', 'Ġself', '.', 'is', '_', 'present', '(', 'self', '.', 'env', '.', 'default', '_', 'hostname', ')', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġif', 'Ġdefault', '_', 'host', '_', 'present', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġif', 'Ġself', '.', 'verbose', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġprint', "('", 'Target', 'Ġhost', 'Ġmissing', 'Ġand', 'Ġdefault', 'Ġhost', 'Ġpresent', 'Ġso', 'Ġhost', 'Ġinit', 'Ġrequired', ".')", 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġret', 'Ġ=', 'ĠTrue', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġelse', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġif', 'Ġself', '.', 'verbose', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġprint', "('", 'Target', 'Ġhost', 'Ġmissing', 'Ġbut', 'Ġdefault', 'Ġhost', 'Ġalso', 'Ġmissing', ',', "Ġ'", 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', "Ġ'", 'so', 'Ġno', 'Ġhost', 'Ġinit', 'Ġrequired', ".')", 'Ċ', 'Ċ', 'Ċ', 'Ċ', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġelse', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġif', 'Ġself', '.', 'verbose', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġprint', "('", 'Target', 'Ġhost', 'Ġis', 'Ġpresent', 'Ġso', 'Ġno', 'Ġhost', 'Ġinit', 'Ġrequired', ".')", 'Ċ', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġreturn', 'Ġret', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_CONSTANT_EXPR_CONSTANT_ASSIGN_NAME_STORE_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_IF_UNARYOP_NOT_NAME_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_IF_NAME_LOAD_IF_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_NAME_LOAD_CONSTANT_ASSIGN_NAME_STORE_CONSTANT_IF_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_NAME_LOAD_CONSTANT_IF_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_NAME_LOAD_CONSTANT_RETURN_NAME_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_CONSTANT_EXPR_CONSTANT_ASSIGN_NAME_STORE_', 'CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'IF_UNARYOP_NOT_NAME_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_', 'IF_NAME_LOAD_', 'IF_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_NAME_LOAD_', 'CONSTANT_ASSIGN_NAME_STORE_CONSTANT_', 'IF_ATTRIBUTE_NAME_LOAD_LOAD_', 'EXPR_CALL_NAME_LOAD_CONSTANT_', 'IF_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_NAME_LOAD_', 'CONSTANT_RETURN_NAME_LOAD']
#
#
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def fix(x, digs):
#
#     if type(x) != type(''): x = repr(x)
#     try:
#         sign, intpart, fraction, expo = extract(x)
#     except NotANumber:
#         return x
#     intpart, fraction = unexpo(intpart, fraction, expo)
#     intpart, fraction = roundfrac(intpart, fraction, digs)
#     while intpart and intpart[0] == '0': intpart = intpart[1:]
#     if intpart == '': intpart = '0'
#     if digs > 0: return sign + intpart + '.' + fraction
#     else: return sign + intpart
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġfix', '(', 'x', ',', 'Ġd', 'igs', '):', 'Ċ', 'ĠĠĠĠĊ', 'ĠĠĠ', 'Ġif', 'Ġtype', '(', 'x', ')', 'Ġ!=', 'Ġtype', "('", "'):", 'Ġx', 'Ġ=', 'Ġrepr', '(', 'x', ')', 'Ċ', 'ĠĠĠ', 'Ġtry', ':', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġsign', ',', 'Ġint', 'part', ',', 'Ġfraction', ',', 'Ġex', 'po', 'Ġ=', 'Ġextract', '(', 'x', ')', 'Ċ', 'ĠĠĠ', 'Ġexcept', 'ĠNot', 'AN', 'umber', ':', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġreturn', 'Ġx', 'Ċ', 'ĠĠĠ', 'Ġint', 'part', ',', 'Ġfraction', 'Ġ=', 'Ġun', 'ex', 'po', '(', 'int', 'part', ',', 'Ġfraction', ',', 'Ġex', 'po', ')', 'Ċ', 'ĠĠĠ', 'Ġint', 'part', ',', 'Ġfraction', 'Ġ=', 'Ġround', 'frac', '(', 'int', 'part', ',', 'Ġfraction', ',', 'Ġd', 'igs', ')', 'Ċ', 'ĠĠĠ', 'Ġwhile', 'Ġint', 'part', 'Ġand', 'Ġint', 'part', '[', '0', ']', 'Ġ==', "Ġ'", '0', "':", 'Ġint', 'part', 'Ġ=', 'Ġint', 'part', '[', '1', ':]', 'Ċ', 'ĠĠĠ', 'Ġif', 'Ġint', 'part', 'Ġ==', "Ġ'':", 'Ġint', 'part', 'Ġ=', "Ġ'", '0', "'", 'Ċ', 'ĠĠĠ', 'Ġif', 'Ġd', 'igs', 'Ġ>', 'Ġ0', ':', 'Ġreturn', 'Ġsign', 'Ġ+', 'Ġint', 'part', 'Ġ+', "Ġ'.'", 'Ġ+', 'Ġfraction', 'Ċ', 'ĠĠĠ', 'Ġelse', ':', 'Ġreturn', 'Ġsign', 'Ġ+', 'Ġint', 'part', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_IF_BOOLOP_AND_COMPARE_CONSTANT_IN_NAME_LOAD_COMPARE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ISNOT_CONSTANT_EXPR_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_BINOP_CONSTANT_ADD_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_BINOP_CONSTANT_MOD_DICT_CONSTANT_CONSTANT_ATTRIBUTE_NAME_LOAD_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_KEYWORD_NAME_LOAD_TRY_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_EXCEPTHANDLER_EXPR_CALL_NAME_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_RAISE_RETURN_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_EXPR_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_BINOP_CONSTANT_ADD_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_KEYWORD_NAME_LOAD_TRY_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_EXCEPTHANDLER_EXPR_CALL_NAME_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_RAISE_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_RETURN_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_IF_BOOLOP_AND_', 'COMPARE_CONSTANT_IN_NAME_LOAD_', 'COMPARE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ISNOT_CONSTANT_', 'EXPR_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_BINOP_CONSTANT_ADD_', 'CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_', 'BINOP_CONSTANT_MOD_', 'DICT_CONSTANT_CONSTANT_ATTRIBUTE_NAME_LOAD_LOAD_', 'SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_NAME_STORE_', 'CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_', 'KEYWORD_NAME_LOAD_', 'TRY_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'EXCEPTHANDLER_EXPR_', 'CALL_NAME_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_', 'RAISE_', 'RETURN_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_', 'EXPR_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_BINOP_CONSTANT_ADD_', 'CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_', 'ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_', 'KEYWORD_NAME_LOAD_', 'TRY_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'EXCEPTHANDLER_EXPR_', 'CALL_NAME_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_', 'RAISE_', 'ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'RETURN_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_IF_COMPARE_CALL_NAME_LOAD_NAME_LOAD_NOTEQ_CALL_NAME_LOAD_CONSTANT_ASSIGN_NAME_STORE_CALL_NAME_LOAD_NAME_LOAD_TRY_ASSIGN_TUPLE_NAME_STORE_NAME_STORE_NAME_STORE_NAME_STORE_STORE_CALL_NAME_LOAD_NAME_LOAD_EXCEPTHANDLER_NAME_LOAD_RETURN_NAME_LOAD_ASSIGN_TUPLE_NAME_STORE_NAME_STORE_STORE_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_NAME_LOAD_ASSIGN_TUPLE_NAME_STORE_NAME_STORE_STORE_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_NAME_LOAD_WHILE_BOOLOP_AND_NAME_LOAD_COMPARE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_EQ_CONSTANT_ASSIGN_NAME_STORE_SUBSCRIPT_NAME_LOAD_SLICE_CONSTANT_LOAD_IF_COMPARE_NAME_LOAD_EQ_CONSTANT_ASSIGN_NAME_STORE_CONSTANT_IF_COMPARE_NAME_LOAD_GT_CONSTANT_RETURN_BINOP_BINOP_BINOP_NAME_LOAD_ADD_NAME_LOAD_ADD_CONSTANT_ADD_NAME_LOAD_RETURN_BINOP_NAME_LOAD_ADD_NAME_LOAD
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def cluster_text_input(cluster, title=None):
#
#     if not title:
#         title = 'Type in the name of your cluster and press Enter/Return:'
#     return TextInput(value=cluster.name, title=title)
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġcluster', '_', 'text', '_', 'input', '(', 'cluster', ',', 'Ġtitle', '=', 'None', '):', 'Ċ', 'ĠĠĠĠĊ', 'ĠĠĠ', 'Ġif', 'Ġnot', 'Ġtitle', ':', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġtitle', 'Ġ=', "Ġ'", 'Type', 'Ġin', 'Ġthe', 'Ġname', 'Ġof', 'Ġyour', 'Ġcluster', 'Ġand', 'Ġpress', 'ĠEnter', '/', 'Return', ":'", 'Ċ', 'ĠĠĠ', 'Ġreturn', 'ĠText', 'Input', '(', 'value', '=', 'cluster', '.', 'name', ',', 'Ġtitle', '=', 'title', ')', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_EXPR_CONSTANT_EXPR_CALL_NAME_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_KEYWORD_NAME_LOAD_RETURN_CALL_NAME_LOAD_NAME_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_EXPR_', 'CONSTANT_EXPR_CALL_NAME_LOAD_', 'ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_KEYWORD_NAME_LOAD_', 'RETURN_CALL_NAME_LOAD_NAME_LOAD']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_CONSTANT_EXPR_CONSTANT_IF_UNARYOP_NOT_NAME_LOAD_ASSIGN_NAME_STORE_CONSTANT_RETURN_CALL_NAME_LOAD_KEYWORD_ATTRIBUTE_NAME_LOAD_LOAD_KEYWORD_NAME_LOAD
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def TP_dependent_property_derivative_P(self, T, P, order=1):
#         r
#         sorted_valid_methods_P = self.select_valid_methods_P(T, P)
#         for method in sorted_valid_methods_P:
#             try:
#                 return self.calculate_derivative_P(P, T, method, order)
#             except:
#                 pass
#         return None
#
# Source Tokenization:_____
# ['<s>', 'def', 'ĠTP', '_', 'dependent', '_', 'property', '_', 'derivative', '_', 'P', '(', 'self', ',', 'ĠT', ',', 'ĠP', ',', 'Ġorder', '=', '1', '):', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġr', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġsorted', '_', 'valid', '_', 'methods', '_', 'P', 'Ġ=', 'Ġself', '.', 'select', '_', 'valid', '_', 'methods', '_', 'P', '(', 'T', ',', 'ĠP', ')', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġfor', 'Ġmethod', 'Ġin', 'Ġsorted', '_', 'valid', '_', 'methods', '_', 'P', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġtry', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġreturn', 'Ġself', '.', 'calculate', '_', 'derivative', '_', 'P', '(', 'P', ',', 'ĠT', ',', 'Ġmethod', ',', 'Ġorder', ')', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġexcept', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġpass', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġreturn', 'ĠNone', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_IF_CALL_ATTRIBUTE_NAME_LOAD_LOAD_FOR_TUPLE_NAME_STORE_NAME_STORE_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_IF_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_NAME_LOAD_ASSIGN_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_STORE_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_IF_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'FOR_TUPLE_NAME_STORE_NAME_STORE_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'IF_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_', 'CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_NAME_LOAD_', 'ASSIGN_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_STORE_', 'NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_ARG_ARG_CONSTANT_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_NAME_LOAD_FOR_NAME_STORE_NAME_LOAD_TRY_RETURN_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_NAME_LOAD_NAME_LOAD_NAME_LOAD_EXCEPTHANDLER_PASS_RETURN_CONSTANT
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def write(self, data, assert_ss=True, deassert_ss=True):
#
#
#         if self._mosi is None:
#             raise RuntimeError('Write attempted with no MOSI pin specified.')
#         if assert_ss and self._ss is not None:
#             self._gpio.set_low(self._ss)
#         for byte in data:
#             for i in range(8):
#
#                 if self._write_shift(byte, i) & self._mask:
#                     self._gpio.set_high(self._mosi)
#                 else:
#                     self._gpio.set_low(self._mosi)
#
#                 self._gpio.output(self._sclk, not self._clock_base)
#
#                 self._gpio.output(self._sclk, self._clock_base)
#         if deassert_ss and self._ss is not None:
#             self._gpio.set_high(self._ss)
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġwrite', '(', 'self', ',', 'Ġdata', ',', 'Ġassert', '_', 'ss', '=', 'True', ',', 'Ġde', 'assert', '_', 'ss', '=', 'True', '):', 'Ċ', 'ĠĠĠĠĠĠĠĠĊ', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġif', 'Ġself', '._', 'mos', 'i', 'Ġis', 'ĠNone', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġraise', 'ĠRuntimeError', "('", 'Write', 'Ġattempted', 'Ġwith', 'Ġno', 'ĠMO', 'SI', 'Ġpin', 'Ġspecified', ".')", 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġif', 'Ġassert', '_', 'ss', 'Ġand', 'Ġself', '._', 'ss', 'Ġis', 'Ġnot', 'ĠNone', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġself', '._', 'gpio', '.', 'set', '_', 'low', '(', 'self', '._', 'ss', ')', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġfor', 'Ġbyte', 'Ġin', 'Ġdata', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġfor', 'Ġi', 'Ġin', 'Ġrange', '(', '8', '):', 'Ċ', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġif', 'Ġself', '._', 'write', '_', 'shift', '(', 'byte', ',', 'Ġi', ')', 'Ġ&', 'Ġself', '._', 'mask', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġself', '._', 'gpio', '.', 'set', '_', 'high', '(', 'self', '._', 'mos', 'i', ')', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġelse', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġself', '._', 'gpio', '.', 'set', '_', 'low', '(', 'self', '._', 'mos', 'i', ')', 'Ċ', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġself', '._', 'gpio', '.', 'output', '(', 'self', '._', 'sc', 'lk', ',', 'Ġnot', 'Ġself', '._', 'clock', '_', 'base', ')', 'Ċ', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġself', '._', 'gpio', '.', 'output', '(', 'self', '._', 'sc', 'lk', ',', 'Ġself', '._', 'clock', '_', 'base', ')', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġif', 'Ġde', 'assert', '_', 'ss', 'Ġand', 'Ġself', '._', 'ss', 'Ġis', 'Ġnot', 'ĠNone', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġself', '._', 'gpio', '.', 'set', '_', 'high', '(', 'self', '._', 'ss', ')', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_LIST_LOAD_FOR_NAME_STORE_NAME_LOAD_ASSIGN_NAME_STORE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_NAME_STORE_CONSTANT_ASSIGN_NAME_STORE_CONSTANT_IF_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_ASSIGN_NAME_STORE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_IF_COMPARE_NAME_LOAD_EQ_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_IF_COMPARE_ATTRIBUTE_NAME_LOAD_LOAD_NOTIN_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_RAISE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_DICT_ASSIGN_NAME_STORE_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_LOAD_IF_COMPARE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_EQ_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_NAME_STORE_DICT_CONSTANT_CONSTANT_CONSTANT_CONSTANT_CONSTANT_CONSTANT_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_NAME_LOAD_NAME_LOAD_CONSTANT_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_RETURN_NAME_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_LIST_LOAD_', 'FOR_NAME_STORE_NAME_LOAD_ASSIGN_NAME_STORE_', 'SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_NAME_STORE_', 'CONSTANT_ASSIGN_NAME_STORE_', 'CONSTANT_IF_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_ASSIGN_NAME_STORE_', 'SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_', 'IF_COMPARE_NAME_LOAD_EQ_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_', 'IF_COMPARE_ATTRIBUTE_NAME_LOAD_LOAD_', 'NOTIN_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_', 'RAISE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_', 'DICT_ASSIGN_NAME_STORE_', 'SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_LOAD_', 'IF_COMPARE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_EQ_', 'SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_', 'SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_', 'SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_NAME_STORE_', 'DICT_CONSTANT_CONSTANT_CONSTANT_CONSTANT_CONSTANT_CONSTANT_', 'SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_', 'NAME_LOAD_NAME_LOAD_', 'CONSTANT_NAME_LOAD_', 'EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_RETURN_NAME_LOAD']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_ARG_ARG_CONSTANT_CONSTANT_EXPR_CONSTANT_IF_COMPARE_ATTRIBUTE_NAME_LOAD_LOAD_IS_CONSTANT_RAISE_CALL_NAME_LOAD_CONSTANT_IF_BOOLOP_AND_NAME_LOAD_COMPARE_ATTRIBUTE_NAME_LOAD_LOAD_ISNOT_CONSTANT_EXPR_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_FOR_NAME_STORE_NAME_LOAD_FOR_NAME_STORE_CALL_NAME_LOAD_CONSTANT_IF_BINOP_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_NAME_LOAD_BITAND_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_UNARYOP_NOT_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_IF_BOOLOP_AND_NAME_LOAD_COMPARE_ATTRIBUTE_NAME_LOAD_LOAD_ISNOT_CONSTANT_EXPR_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_ATTRIBUTE_NAME_LOAD_LOAD
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def get_mode(self):
#
#         mode = None
#         int_mode = (yield from self.handle_long(self.API.get('mode')))
#         modes = yield from self.get_modes()
#         for temp_mode in modes:
#             if temp_mode['band'] == int_mode:
#                 mode = temp_mode['label']
#
#         return str(mode)
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġget', '_', 'mode', '(', 'self', '):', 'Ċ', 'ĠĠĠĠĠĠĠĠĊ', 'ĠĠĠĠĠĠĠ', 'Ġmode', 'Ġ=', 'ĠNone', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġint', '_', 'mode', 'Ġ=', 'Ġ(', 'yield', 'Ġfrom', 'Ġself', '.', 'handle', '_', 'long', '(', 'self', '.', 'API', '.', 'get', "('", 'mode', "')))", 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġmodes', 'Ġ=', 'Ġyield', 'Ġfrom', 'Ġself', '.', 'get', '_', 'modes', '()', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġfor', 'Ġtemp', '_', 'mode', 'Ġin', 'Ġmodes', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġif', 'Ġtemp', '_', 'mode', "['", 'band', "']", 'Ġ==', 'Ġint', '_', 'mode', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġmode', 'Ġ=', 'Ġtemp', '_', 'mode', "['", 'label', "']", 'Ċ', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġreturn', 'Ġstr', '(', 'mode', ')', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_IF_COMPARE_ATTRIBUTE_NAME_LOAD_LOAD_EQ_NAME_LOAD_ASSIGN_ATTRIBUTE_NAME_LOAD_STORE_ATTRIBUTE_NAME_LOAD_LOAD_IF_COMPARE_ATTRIBUTE_NAME_LOAD_LOAD_EQ_NAME_LOAD_ASSIGN_ATTRIBUTE_NAME_LOAD_STORE_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_DELETE_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_DEL_AUGASSIGN_ATTRIBUTE_NAME_LOAD_STORE_SUB_CONSTANT
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_', 'IF_COMPARE_ATTRIBUTE_NAME_LOAD_LOAD_EQ_NAME_LOAD_', 'ASSIGN_ATTRIBUTE_NAME_LOAD_STORE_ATTRIBUTE_NAME_LOAD_LOAD_', 'IF_COMPARE_ATTRIBUTE_NAME_LOAD_LOAD_EQ_NAME_LOAD_', 'ASSIGN_ATTRIBUTE_NAME_LOAD_STORE_', 'ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'DELETE_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_', 'ATTRIBUTE_NAME_LOAD_LOAD_', 'DEL', '_AUG', 'ASSIGN_ATTRIBUTE_NAME_LOAD_STORE_', 'SUB_', 'CONSTANT']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CONSTANT_ASSIGN_NAME_STORE_YIELDFROM_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_CONSTANT_ASSIGN_NAME_STORE_YIELDFROM_CALL_ATTRIBUTE_NAME_LOAD_LOAD_FOR_NAME_STORE_NAME_LOAD_IF_COMPARE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_EQ_NAME_LOAD_ASSIGN_NAME_STORE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_RETURN_CALL_NAME_LOAD_NAME_LOAD
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def as_dict(self):
#
#         entry_dict = {}
#         entry_dict['UUID'] = self.uuid
#         entry_dict['Creation Date'] = self.time
#         entry_dict['Time Zone'] = self.tz
#         if self.tags:
#             entry_dict['Tags'] = self.tags
#         entry_dict['Entry Text'] = self.text
#         entry_dict['Starred'] = self.starred
#         entry_dict['Location'] = self.location
#         return entry_dict
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġas', '_', 'dict', '(', 'self', '):', 'Ċ', 'ĠĠĠĠĠĠĠĠĊ', 'ĠĠĠĠĠĠĠ', 'Ġentry', '_', 'dict', 'Ġ=', 'Ġ{}', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġentry', '_', 'dict', "['", 'UUID', "']", 'Ġ=', 'Ġself', '.', 'uuid', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġentry', '_', 'dict', "['", 'Creation', 'ĠDate', "']", 'Ġ=', 'Ġself', '.', 'time', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġentry', '_', 'dict', "['", 'Time', 'ĠZone', "']", 'Ġ=', 'Ġself', '.', 'tz', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġif', 'Ġself', '.', 'tags', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġentry', '_', 'dict', "['", 'Tags', "']", 'Ġ=', 'Ġself', '.', 'tags', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġentry', '_', 'dict', "['", 'Entry', 'ĠText', "']", 'Ġ=', 'Ġself', '.', 'text', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġentry', '_', 'dict', "['", 'Star', 'red', "']", 'Ġ=', 'Ġself', '.', 'star', 'red', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġentry', '_', 'dict', "['", 'Location', "']", 'Ġ=', 'Ġself', '.', 'location', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġreturn', 'Ġentry', '_', 'dict', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_KEYWORD_CONSTANT_KEYWORD_CONSTANT_KEYWORD_CONSTANT_FOR_NAME_STORE_NAME_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_KEYWORD_CONSTANT_IF_NAME_LOAD_RETURN_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_KEYWORD_CONSTANT_RETURN_CONSTANT
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_', 'ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_ASSIGN_NAME_STORE_', 'CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_', 'KEYWORD_CONSTANT_KEYWORD_CONSTANT_KEYWORD_CONSTANT_', 'FOR_NAME_STORE_NAME_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_', 'KEYWORD_CONSTANT_IF_NAME_LOAD_', 'RETURN_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_', 'KEYWORD_CONSTANT_', 'RETURN_CONSTANT']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_DICT_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_ATTRIBUTE_NAME_LOAD_LOAD_IF_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_ATTRIBUTE_NAME_LOAD_LOAD_RETURN_NAME_LOAD
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def _munge_whitespace(self, text):
#
#         if self.expand_tabs:
#
#             text = ' '.join((' '.join(text.split('\n'))).split('\t'))
#         if self.replace_whitespace:
#
#
#
#
#             text = ' '.join(' '.join(text.split('\n')).split('\t'))
#         return text
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġ_', 'mun', 'ge', '_', 'whitespace', '(', 'self', ',', 'Ġtext', '):', 'Ċ', 'ĠĠĠĠĠĠĠĠĊ', 'ĠĠĠĠĠĠĠ', 'Ġif', 'Ġself', '.', 'expand', '_', 'tabs', ':', 'Ċ', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġtext', 'Ġ=', "Ġ'", "Ġ'.", 'join', "(('", "Ġ'.", 'join', '(', 'text', '.', 'split', "('\\", 'n', "'))", ').', 'split', "('\\", 't', "'))", 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġif', 'Ġself', '.', 'replace', '_', 'whitespace', ':', 'Ċ', 'Ċ', 'Ċ', 'Ċ', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġtext', 'Ġ=', "Ġ'", "Ġ'.", 'join', "('", "Ġ'.", 'join', '(', 'text', '.', 'split', "('\\", 'n', "')).", 'split', "('\\", 't', "'))", 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġreturn', 'Ġtext', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_CONSTANT_EXPR_CONSTANT_IF_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_RETURN_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_FOR_NAME_STORE_ATTRIBUTE_NAME_LOAD_LOAD_IF_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_ASSIGN_ATTRIBUTE_NAME_LOAD_STORE_NAME_LOAD_RETURN_NAME_LOAD_ASSIGN_ATTRIBUTE_NAME_LOAD_STORE_NAME_LOAD_RETURN_NAME_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_CONSTANT_EXPR_', 'CONSTANT_IF_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_', 'RETURN_CALL_NAME_LOAD_NAME_LOAD_', 'NAME_LOAD_ASSIGN_NAME_STORE_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_', 'FOR_NAME_STORE_ATTRIBUTE_NAME_LOAD_LOAD_', 'IF_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_', 'ASSIGN_ATTRIBUTE_NAME_LOAD_STORE_', 'NAME_LOAD_RETURN_', 'NAME_LOAD_ASSIGN_ATTRIBUTE_NAME_LOAD_STORE_', 'NAME_LOAD_RETURN_NAME_LOAD']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_IF_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_CONSTANT_LOAD_CALL_ATTRIBUTE_CALL_ATTRIBUTE_CONSTANT_LOAD_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_LOAD_CONSTANT_IF_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_CONSTANT_LOAD_CALL_ATTRIBUTE_CALL_ATTRIBUTE_CONSTANT_LOAD_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_LOAD_CONSTANT_RETURN_NAME_LOAD
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def driver_from_file(input_file):
#
#     file_ext = os.path.splitext(input_file)[1].split(".")[1]
#     if file_ext not in _file_ext_to_driver():
#         raise MapcheteDriverError(
#             "no driver could be found for file extension %s" % file_ext
#         )
#     driver = _file_ext_to_driver()[file_ext]
#     if len(driver) > 1:
#         warnings.warn(
#             DeprecationWarning(
#                 "more than one driver for file found, taking %s" % driver[0]
#             )
#         )
#     return driver[0]
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġdriver', '_', 'from', '_', 'file', '(', 'input', '_', 'file', '):', 'Ċ', 'ĠĠĠĠĊ', 'ĠĠĠ', 'Ġfile', '_', 'ext', 'Ġ=', 'Ġos', '.', 'path', '.', 'splitext', '(', 'input', '_', 'file', ')[', '1', '].', 'split', '(".")[', '1', ']', 'Ċ', 'ĠĠĠ', 'Ġif', 'Ġfile', '_', 'ext', 'Ġnot', 'Ġin', 'Ġ_', 'file', '_', 'ext', '_', 'to', '_', 'driver', '():', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġraise', 'ĠMap', 'ch', 'ete', 'Driver', 'Error', '(', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġ"', 'no', 'Ġdriver', 'Ġcould', 'Ġbe', 'Ġfound', 'Ġfor', 'Ġfile', 'Ġextension', 'Ġ%', 's', '"', 'Ġ%', 'Ġfile', '_', 'ext', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġ)', 'Ċ', 'ĠĠĠ', 'Ġdriver', 'Ġ=', 'Ġ_', 'file', '_', 'ext', '_', 'to', '_', 'driver', '()[', 'file', '_', 'ext', ']', 'Ċ', 'ĠĠĠ', 'Ġif', 'Ġlen', '(', 'driver', ')', 'Ġ>', 'Ġ1', ':', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġwarnings', '.', 'warn', '(', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'ĠDeprecationWarning', '(', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġ"', 'more', 'Ġthan', 'Ġone', 'Ġdriver', 'Ġfor', 'Ġfile', 'Ġfound', ',', 'Ġtaking', 'Ġ%', 's', '"', 'Ġ%', 'Ġdriver', '[', '0', ']', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġ)', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġ)', 'Ċ', 'ĠĠĠ', 'Ġreturn', 'Ġdriver', '[', '0', ']', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CALL_ATTRIBUTE_CONSTANT_LOAD_NAME_LOAD_KEYWORD_CONSTANT_TRY_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_EXCEPTHANDLER_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CALL_NAME_LOAD_CONSTANT_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_RETURN_IF_CALL_NAME_LOAD_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CALL_NAME_LOAD_CONSTANT
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_', 'EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CALL_ATTRIBUTE_CONSTANT_LOAD_NAME_LOAD_', 'KEYWORD_CONSTANT_', 'TRY_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_', 'EXCEPTHANDLER_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'CALL_NAME_LOAD_CONSTANT_', 'EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_RETURN_', 'IF_CALL_NAME_LOAD_', 'SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_LOAD_', 'ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_LOAD_', 'EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'CALL_NAME_LOAD_CONSTANT']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_SUBSCRIPT_CALL_ATTRIBUTE_SUBSCRIPT_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_CONSTANT_LOAD_LOAD_CONSTANT_CONSTANT_LOAD_IF_COMPARE_NAME_LOAD_NOTIN_CALL_NAME_LOAD_RAISE_CALL_NAME_LOAD_BINOP_CONSTANT_MOD_NAME_LOAD_ASSIGN_NAME_STORE_SUBSCRIPT_CALL_NAME_LOAD_NAME_LOAD_LOAD_IF_COMPARE_CALL_NAME_LOAD_NAME_LOAD_GT_CONSTANT_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CALL_NAME_LOAD_BINOP_CONSTANT_MOD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_RETURN_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def outer_right_join(self, join_streamlet, window_config, join_function):
#
#     from heronpy.streamlet.impl.joinbolt import JoinStreamlet, JoinBolt
#     join_streamlet_result = JoinStreamlet(JoinBolt.OUTER_RIGHT, window_config,
#                                           join_function, self, join_streamlet)
#     self._add_child(join_streamlet_result)
#     join_streamlet._add_child(join_streamlet_result)
#     return join_streamlet_result
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġouter', '_', 'right', '_', 'join', '(', 'self', ',', 'Ġjoin', '_', 'stream', 'let', ',', 'Ġwindow', '_', 'config', ',', 'Ġjoin', '_', 'function', '):', 'Ċ', 'ĠĠĠĠĊ', 'ĠĠĠ', 'Ġfrom', 'Ġh', 'eron', 'py', '.', 'stream', 'let', '.', 'impl', '.', 'join', 'bolt', 'Ġimport', 'ĠJoin', 'Stream', 'let', ',', 'ĠJoin', 'Bolt', 'Ċ', 'ĠĠĠ', 'Ġjoin', '_', 'stream', 'let', '_', 'result', 'Ġ=', 'ĠJoin', 'Stream', 'let', '(', 'Join', 'Bolt', '.', 'OUTER', '_', 'RIGHT', ',', 'Ġwindow', '_', 'config', ',', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġjoin', '_', 'function', ',', 'Ġself', ',', 'Ġjoin', '_', 'stream', 'let', ')', 'Ċ', 'ĠĠĠ', 'Ġself', '._', 'add', '_', 'child', '(', 'join', '_', 'stream', 'let', '_', 'result', ')', 'Ċ', 'ĠĠĠ', 'Ġjoin', '_', 'stream', 'let', '._', 'add', '_', 'child', '(', 'join', '_', 'stream', 'let', '_', 'result', ')', 'Ċ', 'ĠĠĠ', 'Ġreturn', 'Ġjoin', '_', 'stream', 'let', '_', 'result', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_ARG_ARG_CONSTANT_EXPR_CONSTANT_IF_NAME_LOAD_ASSIGN_NAME_STORE_LIST_CONSTANT_LOAD_ASSIGN_NAME_STORE_BINOP_NAME_LOAD_ADD_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_LIST_LOAD_ASSIGN_NAME_STORE_BINOP_NAME_LOAD_ADD_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_RETURN_NAME_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_ARG_ARG_CONSTANT_EXPR_', 'CONSTANT_IF_NAME_LOAD_ASSIGN_NAME_STORE_', 'LIST_CONSTANT_LOAD_ASSIGN_NAME_STORE_', 'BINOP_NAME_LOAD_ADD_', 'CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_', 'LIST_LOAD_ASSIGN_NAME_STORE_', 'BINOP_NAME_LOAD_ADD_', 'CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_RETURN_NAME_LOAD']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_ARG_ARG_EXPR_CONSTANT_IMPORTFROM_ALIAS_ALIAS_ASSIGN_NAME_STORE_CALL_NAME_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_NAME_LOAD_NAME_LOAD_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_RETURN_NAME_LOAD
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def _readNamelist(currentlyIncluding, cache, namFilename, unique_glyphs):
#
#
#   filename = os.path.abspath(os.path.normcase(namFilename))
#   if filename in currentlyIncluding:
#     raise NamelistRecursionError(filename)
#   currentlyIncluding.add(filename)
#   try:
#     result = __readNamelist(cache, filename, unique_glyphs)
#   finally:
#     currentlyIncluding.remove(filename)
#   return result
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġ_', 'read', 'Name', 'list', '(', 'currently', 'Including', ',', 'Ġcache', ',', 'Ġnam', 'Filename', ',', 'Ġunique', '_', 'glyphs', '):', 'Ċ', 'ĠĠĊ', 'Ċ', 'Ġ', 'Ġfilename', 'Ġ=', 'Ġos', '.', 'path', '.', 'abspath', '(', 'os', '.', 'path', '.', 'norm', 'case', '(', 'nam', 'Filename', '))', 'Ċ', 'Ġ', 'Ġif', 'Ġfilename', 'Ġin', 'Ġcurrently', 'Including', ':', 'Ċ', 'ĠĠĠ', 'Ġraise', 'ĠName', 'list', 'Recursion', 'Error', '(', 'filename', ')', 'Ċ', 'Ġ', 'Ġcurrently', 'Including', '.', 'add', '(', 'filename', ')', 'Ċ', 'Ġ', 'Ġtry', ':', 'Ċ', 'ĠĠĠ', 'Ġresult', 'Ġ=', 'Ġ__', 'read', 'Name', 'list', '(', 'cache', ',', 'Ġfilename', ',', 'Ġunique', '_', 'glyphs', ')', 'Ċ', 'Ġ', 'Ġfinally', ':', 'Ċ', 'ĠĠĠ', 'Ġcurrently', 'Including', '.', 'remove', '(', 'filename', ')', 'Ċ', 'Ġ', 'Ġreturn', 'Ġresult', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_IF_CALL_ATTRIBUTE_NAME_LOAD_LOAD_WHILE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_PASS_RETURN_IF_BOOLOP_AND_UNARYOP_NOT_CALL_ATTRIBUTE_NAME_LOAD_LOAD_UNARYOP_NOT_CALL_ATTRIBUTE_NAME_LOAD_LOAD_UNARYOP_NOT_CALL_ATTRIBUTE_NAME_LOAD_LOAD_UNARYOP_NOT_CALL_ATTRIBUTE_NAME_LOAD_LOAD_RAISE_CALL_NAME_LOAD_BINOP_CONSTANT_ADD_ATTRIBUTE_NAME_LOAD_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_IF_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'WHILE_', 'CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'PASS_', 'RETURN_', 'IF_BOOLOP_AND_', 'UNARYOP_NOT_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'UNARYOP_NOT_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'UNARYOP_NOT_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'UNARYOP_NOT_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'RAISE_CALL_NAME_LOAD_BINOP_CONSTANT_ADD_', 'ATTRIBUTE_NAME_LOAD_LOAD']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_ARG_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_IF_COMPARE_NAME_LOAD_IN_NAME_LOAD_RAISE_CALL_NAME_LOAD_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_TRY_ASSIGN_NAME_STORE_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_RETURN_NAME_LOAD
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def GetColumnHeaders(self) -> list:
#
#         eleArray = self.pattern.GetCurrentColumnHeaders()
#         if eleArray:
#             controls = []
#             for i in range(eleArray.Length):
#                 ele = eleArray.GetElement(i)
#                 con = Control.CreateControlFromElement(element=ele)
#                 if con:
#                     controls.append(con)
#             return controls
#         return []
#
# Source Tokenization:_____
# ['<s>', 'def', 'ĠGet', 'Column', 'Headers', '(', 'self', ')', 'Ġ->', 'Ġlist', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĊ', 'ĠĠĠĠĠĠĠ', 'Ġele', 'Array', 'Ġ=', 'Ġself', '.', 'pattern', '.', 'GetCurrent', 'Column', 'Headers', '()', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġif', 'Ġele', 'Array', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġcontrols', 'Ġ=', 'Ġ[]', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġfor', 'Ġi', 'Ġin', 'Ġrange', '(', 'ele', 'Array', '.', 'Length', '):', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġele', 'Ġ=', 'Ġele', 'Array', '.', 'Get', 'Element', '(', 'i', ')', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġcon', 'Ġ=', 'ĠControl', '.', 'Create', 'Control', 'FromElement', '(', 'element', '=', 'ele', ')', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġif', 'Ġcon', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġcontrols', '.', 'append', '(', 'con', ')', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġreturn', 'Ġcontrols', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġreturn', 'Ġ[]', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_STORE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_IF_UNARYOP_NOT_CALL_NAME_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_DICT_FOR_TUPLE_NAME_STORE_NAME_STORE_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_NAME_LOAD_STORE_DICTCOMP_NAME_LOAD_DICT_COMPREHENSION_NAME_STORE_NAME_LOAD_ASSIGN_NAME_STORE_NAME_LOAD_RETURN_NAME_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'ASSIGN_SUBSCRIPT_NAME_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_STORE_', 'SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_', 'IF_UNARYOP_NOT_', 'CALL_NAME_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_', 'NAME_LOAD_ASSIGN_NAME_STORE_', 'DICT_FOR_TUPLE_NAME_STORE_NAME_STORE_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'ASSIGN_SUBSCRIPT_NAME_LOAD_NAME_LOAD_STORE_', 'DICTCOMP_NAME_LOAD_', 'DICT_', 'COMPREHENSION_NAME_STORE_NAME_LOAD_ASSIGN_NAME_STORE_', 'NAME_LOAD_RETURN_NAME_LOAD']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_IF_NAME_LOAD_ASSIGN_NAME_STORE_LIST_LOAD_FOR_NAME_STORE_CALL_NAME_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_KEYWORD_NAME_LOAD_IF_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_RETURN_NAME_LOAD_RETURN_LIST_LOAD_NAME_LOAD
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def doc(func):
#
#     stripped_chars = " \t"
#
#     if hasattr(func, '__doc__'):
#         docstring = func.__doc__.lstrip(" \n\t")
#         if "\n" in docstring:
#             i = docstring.index("\n")
#             return docstring[:i].rstrip(stripped_chars)
#         elif docstring:
#             return docstring.rstrip(stripped_chars)
#
#     return ""
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġdoc', '(', 'func', '):', 'Ċ', 'ĠĠĠĠĊ', 'ĠĠĠ', 'Ġstripped', '_', 'chars', 'Ġ=', 'Ġ"', 'Ġ\\', 't', '"', 'Ċ', 'Ċ', 'ĠĠĠ', 'Ġif', 'Ġhasattr', '(', 'func', ',', "Ġ'__", 'doc', "__'):", 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġdocstring', 'Ġ=', 'Ġfunc', '.__', 'doc', '__.', 'lstrip', '("', 'Ġ\\', 'n', '\\', 't', '")', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġif', 'Ġ"\\', 'n', '"', 'Ġin', 'Ġdocstring', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġi', 'Ġ=', 'Ġdocstring', '.', 'index', '("\\', 'n', '")', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġreturn', 'Ġdocstring', '[:', 'i', '].', 'rstrip', '(', 'stripped', '_', 'chars', ')', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġelif', 'Ġdocstring', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġreturn', 'Ġdocstring', '.', 'rstrip', '(', 'stripped', '_', 'chars', ')', 'Ċ', 'Ċ', 'ĠĠĠ', 'Ġreturn', 'Ġ""', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_CALL_ATTRIBUTE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_LOAD_IF_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_RETURN_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_', 'ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_', 'CALL_ATTRIBUTE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_LOAD_', 'IF_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_', 'CALL_ATTRIBUTE_NAME_LOAD_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_', 'RETURN_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CONSTANT_IF_CALL_NAME_LOAD_NAME_LOAD_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_CONSTANT_IF_COMPARE_CONSTANT_IN_NAME_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_RETURN_CALL_ATTRIBUTE_SUBSCRIPT_NAME_LOAD_SLICE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_IF_NAME_LOAD_RETURN_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_RETURN_CONSTANT
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def serialize(element):
#
#     if getattr(_THREAD, "serializer", None) is None:
#         _THREAD.serializer = XMPPSerializer("jabber:client")
#         _THREAD.serializer.emit_head(None, None)
#     return _THREAD.serializer.emit_stanza(element)
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġserialize', '(', 'element', '):', 'Ċ', 'ĠĠĠĠĊ', 'ĠĠĠ', 'Ġif', 'Ġgetattr', '(_', 'THREAD', ',', 'Ġ"', 'serializer', '",', 'ĠNone', ')', 'Ġis', 'ĠNone', ':', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġ_', 'THREAD', '.', 'serializer', 'Ġ=', 'ĠXMPP', 'Serializer', '("', 'j', 'ab', 'ber', ':', 'client', '")', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġ_', 'THREAD', '.', 'serializer', '.', 'emit', '_', 'head', '(', 'None', ',', 'ĠNone', ')', 'Ċ', 'ĠĠĠ', 'Ġreturn', 'Ġ_', 'THREAD', '.', 'serializer', '.', 'emit', '_', 'stanza', '(', 'element', ')', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_CONSTANT_CONSTANT_KEYWORD_CONSTANT_KEYWORD_DICT_CONSTANT_CONSTANT_KEYWORD_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_RETURN_LISTCOMP_ATTRIBUTE_NAME_LOAD_LOAD_COMPREHENSION_NAME_STORE_ATTRIBUTE_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'EXPR_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_CONSTANT_CONSTANT_', 'KEYWORD_CONSTANT_KEYWORD_', 'DICT_CONSTANT_CONSTANT_', 'KEYWORD_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'RETURN_', 'LISTCOMP_ATTRIBUTE_NAME_LOAD_LOAD_COMPREHENSION_NAME_STORE_', 'ATTRIBUTE_', 'ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_LOAD']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_IF_COMPARE_CALL_NAME_LOAD_NAME_LOAD_CONSTANT_CONSTANT_IS_CONSTANT_ASSIGN_ATTRIBUTE_NAME_LOAD_STORE_CALL_NAME_LOAD_CONSTANT_EXPR_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_CONSTANT_CONSTANT_RETURN_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def admin_link_move_down(obj, link_text='down'):
#
#     if obj.rank == obj.grouped_filter().count():
#         return ''
#
#     content_type = ContentType.objects.get_for_model(obj)
#     link = reverse('awl-rankedmodel-move', args=(content_type.id, obj.id,
#         obj.rank + 1))
#
#     return '<a href="%s">%s</a>' % (link, link_text)
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġadmin', '_', 'link', '_', 'move', '_', 'down', '(', 'obj', ',', 'Ġlink', '_', 'text', "='", 'down', "'):", 'Ċ', 'ĠĠĠĠĊ', 'ĠĠĠ', 'Ġif', 'Ġobj', '.', 'rank', 'Ġ==', 'Ġobj', '.', 'grouped', '_', 'filter', '().', 'count', '():', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġreturn', "Ġ''", 'Ċ', 'Ċ', 'ĠĠĠ', 'Ġcontent', '_', 'type', 'Ġ=', 'ĠContentType', '.', 'objects', '.', 'get', '_', 'for', '_', 'model', '(', 'obj', ')', 'Ċ', 'ĠĠĠ', 'Ġlink', 'Ġ=', 'Ġreverse', "('", 'aw', 'l', '-', 'ranked', 'model', '-', 'move', "',", 'Ġargs', '=(', 'content', '_', 'type', '.', 'id', ',', 'Ġobj', '.', 'id', ',', 'ĠĊ', 'ĠĠĠĠĠĠĠ', 'Ġobj', '.', 'rank', 'Ġ+', 'Ġ1', '))', 'Ċ', 'Ċ', 'ĠĠĠ', 'Ġreturn', "Ġ'<", 'a', 'Ġhref', '="%', 's', '">%', 's', '</', 'a', ">'", 'Ġ%', 'Ġ(', 'link', ',', 'Ġlink', '_', 'text', ')', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_ASSERT_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_CONSTANT_IF_UNARYOP_NOT_ATTRIBUTE_NAME_LOAD_LOAD_IF_ATTRIBUTE_NAME_LOAD_LOAD_FOR_NAME_STORE_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_STORE_NAME_LOAD_RETURN_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_RETURN_CONSTANT_IF_COMPARE_NAME_LOAD_IN_ATTRIBUTE_NAME_LOAD_LOAD_RETURN_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CALL_ATTRIBUTE_CONSTANT_LOAD_NAME_LOAD_RETURN_CONSTANT
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_ASSERT_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_', 'CONSTANT_IF_UNARYOP_NOT_ATTRIBUTE_NAME_LOAD_LOAD_', 'IF_ATTRIBUTE_NAME_LOAD_LOAD_FOR_NAME_STORE_ATTRIBUTE_NAME_LOAD_LOAD_', 'ASSIGN_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_STORE_', 'NAME_LOAD_RETURN_', 'SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_LOAD_', 'EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_RETURN_CONSTANT_', 'IF_COMPARE_NAME_LOAD_IN_ATTRIBUTE_NAME_LOAD_LOAD_RETURN_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_LOAD_', 'EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CALL_ATTRIBUTE_CONSTANT_LOAD_', 'NAME_LOAD_RETURN_CONSTANT']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_CONSTANT_EXPR_CONSTANT_IF_COMPARE_ATTRIBUTE_NAME_LOAD_LOAD_EQ_CALL_ATTRIBUTE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_RETURN_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_CALL_NAME_LOAD_CONSTANT_KEYWORD_TUPLE_ATTRIBUTE_NAME_LOAD_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_BINOP_ATTRIBUTE_NAME_LOAD_LOAD_ADD_CONSTANT_LOAD_RETURN_BINOP_CONSTANT_MOD_TUPLE_NAME_LOAD_NAME_LOAD_LOAD
# For label RELATED, model predicted NOT RELATED.
#
# Source:_____
# def bond_task(
#     perc_graph_result, seeds, ps, convolution_factors_tasks_iterator
# ):
#
#
#
#     convolution_factors_tasks = list(convolution_factors_tasks_iterator)
#
#     return reduce(
#         percolate.hpc.bond_reduce,
#         map(
#             bond_run,
#             itertools.repeat(perc_graph_result),
#             seeds,
#             itertools.repeat(ps),
#             itertools.repeat(convolution_factors_tasks),
#         )
#     )
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġbond', '_', 'task', '(', 'Ċ', 'ĠĠĠ', 'Ġperc', '_', 'graph', '_', 'result', ',', 'Ġseeds', ',', 'Ġps', ',', 'Ġconvolution', '_', 'factors', '_', 'tasks', '_', 'iterator', 'Ċ', '):', 'Ċ', 'ĠĠĠĠĊ', 'Ċ', 'Ċ', 'ĠĠĠ', 'Ġconvolution', '_', 'factors', '_', 'tasks', 'Ġ=', 'Ġlist', '(', 'convolution', '_', 'factors', '_', 'tasks', '_', 'iterator', ')', 'Ċ', 'Ċ', 'ĠĠĠ', 'Ġreturn', 'Ġreduce', '(', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġper', 'colate', '.', 'h', 'pc', '.', 'bond', '_', 'reduce', ',', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġmap', '(', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġbond', '_', 'run', ',', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġitertools', '.', 'repeat', '(', 'perc', '_', 'graph', '_', 'result', '),', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġseeds', ',', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġitertools', '.', 'repeat', '(', 'ps', '),', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġitertools', '.', 'repeat', '(', 'convolution', '_', 'factors', '_', 'tasks', '),', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġ)', 'Ċ', 'ĠĠĠ', 'Ġ)', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_ARG_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_NAME_LOAD_NAME_LOAD_RETURN_CALL_NAME_LOAD_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_CALL_NAME_LOAD_NAME_LOAD_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_NAME_LOAD_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_ARG_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_NAME_LOAD_NAME_LOAD_', 'RETURN_CALL_NAME_LOAD_', 'ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_', 'CALL_NAME_LOAD_NAME_LOAD_', 'CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_NAME_LOAD_', 'CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_', 'CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD']
#
#
# For label RELATED, model predicted NOT RELATED.
#
# Source:_____
# def invoke_hook_emit(self, values, stream_id, out_tasks):
#
#     if len(self.task_hooks) > 0:
#       emit_info = EmitInfo(values=values, stream_id=stream_id,
#                            task_id=self.get_task_id(), out_tasks=out_tasks)
#       for task_hook in self.task_hooks:
#         task_hook.emit(emit_info)
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġinvoke', '_', 'hook', '_', 'emit', '(', 'self', ',', 'Ġvalues', ',', 'Ġstream', '_', 'id', ',', 'Ġout', '_', 'tasks', '):', 'Ċ', 'ĠĠĠĠĊ', 'ĠĠĠ', 'Ġif', 'Ġlen', '(', 'self', '.', 'task', '_', 'hooks', ')', 'Ġ>', 'Ġ0', ':', 'Ċ', 'ĠĠĠĠĠ', 'Ġemit', '_', 'info', 'Ġ=', 'ĠEmit', 'Info', '(', 'values', '=', 'values', ',', 'Ġstream', '_', 'id', '=', 'stream', '_', 'id', ',', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġtask', '_', 'id', '=', 'self', '.', 'get', '_', 'task', '_', 'id', '(),', 'Ġout', '_', 'tasks', '=', 'out', '_', 'tasks', ')', 'Ċ', 'ĠĠĠĠĠ', 'Ġfor', 'Ġtask', '_', 'hook', 'Ġin', 'Ġself', '.', 'task', '_', 'hooks', ':', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġtask', '_', 'hook', '.', 'emit', '(', 'emit', '_', 'info', ')', '</s>']
#
# AST:_____
# ...
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_CONSTANT_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'ASSIGN_NAME_STORE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_', 'FOR_NAME_STORE_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_NAME_LOAD_', 'AUGASSIGN_ATTRIBUTE_NAME_LOAD_STORE_ADD_', 'ATTRIBUTE_NAME_LOAD_LOAD_', 'IF_COMPARE_NAME_LOAD_IS_CONSTANT_EXPR_', 'CALL_NAME_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_', 'RETURN_ATTRIBUTE_NAME_LOAD_LOAD']
#
#
# For label RELATED, model predicted NOT RELATED.
#
# Source:_____
# def border_pixels_from_mask(mask):
#
#
#     edge_pixels = edge_pixels_from_mask(mask)
#     masked_grid_index_to_pixel = masked_grid_1d_index_to_2d_pixel_index_from_mask(mask)
#
#     border_pixel_total = total_border_pixels_from_mask_and_edge_pixels(mask, edge_pixels, masked_grid_index_to_pixel)
#
#     border_pixels = np.zeros(border_pixel_total)
#
#     border_pixel_index = 0
#
#     for edge_pixel_index in range(edge_pixels.shape[0]):
#
#         if check_if_border_pixel(mask, edge_pixels[edge_pixel_index], masked_grid_index_to_pixel):
#             border_pixels[border_pixel_index] = edge_pixels[edge_pixel_index]
#             border_pixel_index += 1
#
#     return border_pixels
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġborder', '_', 'pixels', '_', 'from', '_', 'mask', '(', 'mask', '):', 'Ċ', 'ĠĠĠĠĊ', 'Ċ', 'ĠĠĠ', 'Ġedge', '_', 'pixels', 'Ġ=', 'Ġedge', '_', 'pixels', '_', 'from', '_', 'mask', '(', 'mask', ')', 'Ċ', 'ĠĠĠ', 'Ġmasked', '_', 'grid', '_', 'index', '_', 'to', '_', 'pixel', 'Ġ=', 'Ġmasked', '_', 'grid', '_', '1', 'd', '_', 'index', '_', 'to', '_', '2', 'd', '_', 'pixel', '_', 'index', '_', 'from', '_', 'mask', '(', 'mask', ')', 'Ċ', 'Ċ', 'ĠĠĠ', 'Ġborder', '_', 'pixel', '_', 'total', 'Ġ=', 'Ġtotal', '_', 'border', '_', 'pixels', '_', 'from', '_', 'mask', '_', 'and', '_', 'edge', '_', 'pixels', '(', 'mask', ',', 'Ġedge', '_', 'pixels', ',', 'Ġmasked', '_', 'grid', '_', 'index', '_', 'to', '_', 'pixel', ')', 'Ċ', 'Ċ', 'ĠĠĠ', 'Ġborder', '_', 'pixels', 'Ġ=', 'Ġnp', '.', 'zeros', '(', 'border', '_', 'pixel', '_', 'total', ')', 'Ċ', 'Ċ', 'ĠĠĠ', 'Ġborder', '_', 'pixel', '_', 'index', 'Ġ=', 'Ġ0', 'Ċ', 'Ċ', 'ĠĠĠ', 'Ġfor', 'Ġedge', '_', 'pixel', '_', 'index', 'Ġin', 'Ġrange', '(', 'edge', '_', 'pixels', '.', 'shape', '[', '0', ']):', 'Ċ', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġif', 'Ġcheck', '_', 'if', '_', 'border', '_', 'pixel', '(', 'mask', ',', 'Ġedge', '_', 'pixels', '[', 'edge', '_', 'pixel', '_', 'index', '],', 'Ġmasked', '_', 'grid', '_', 'index', '_', 'to', '_', 'pixel', '):', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġborder', '_', 'pixels', '[', 'border', '_', 'pixel', '_', 'index', ']', 'Ġ=', 'Ġedge', '_', 'pixels', '[', 'edge', '_', 'pixel', '_', 'index', ']', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġborder', '_', 'pixel', '_', 'index', 'Ġ+=', 'Ġ1', 'Ċ', 'Ċ', 'ĠĠĠ', 'Ġreturn', 'Ġborder', '_', 'pixels', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_NAME_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_CALL_NAME_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_CONSTANT_FOR_NAME_STORE_CALL_NAME_LOAD_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_LOAD_IF_CALL_NAME_LOAD_NAME_LOAD_SUBSCRIPT_NAME_LOAD_NAME_LOAD_LOAD_NAME_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_NAME_LOAD_STORE_SUBSCRIPT_NAME_LOAD_NAME_LOAD_LOAD_AUGASSIGN_NAME_STORE_ADD_CONSTANT_RETURN_NAME_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_', 'CALL_NAME_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_CALL_NAME_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_', 'CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_NAME_LOAD_', 'ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'NAME_LOAD_ASSIGN_NAME_STORE_CONSTANT_', 'FOR_NAME_STORE_CALL_NAME_LOAD_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_LOAD_', 'IF_CALL_NAME_LOAD_NAME_LOAD_', 'SUBSCRIPT_NAME_LOAD_NAME_LOAD_LOAD_NAME_LOAD_', 'ASSIGN_SUBSCRIPT_NAME_LOAD_NAME_LOAD_STORE_SUBSCRIPT_NAME_LOAD_NAME_LOAD_LOAD_', 'AUGASSIGN_NAME_STORE_ADD_CONSTANT_RETURN_NAME_LOAD']
#
#
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def get(self):
#
#     try:
#       cluster = self.get_argument_cluster()
#       role = self.get_argument_role()
#       environ = self.get_argument_environ()
#       topology_name = self.get_argument_topology()
#       topology_info = self.tracker.getTopologyInfo(topology_name, cluster, role, environ)
#       runtime_state = topology_info["runtime_state"]
#       runtime_state["topology_version"] = topology_info["metadata"]["release_version"]
#       topology = self.tracker.getTopologyByClusterRoleEnvironAndName(
#           cluster, role, environ, topology_name)
#       reg_summary = yield tornado.gen.Task(self.getStmgrsRegSummary, topology.tmaster)
#       for stmgr, reg in reg_summary.items():
#         runtime_state["stmgrs"].setdefault(stmgr, {})["is_registered"] = reg
#       self.write_success_response(runtime_state)
#     except Exception as e:
#       Log.debug(traceback.format_exc())
#       self.write_error_response(e)
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġget', '(', 'self', '):', 'Ċ', 'ĠĠĠĠĊ', 'ĠĠĠ', 'Ġtry', ':', 'Ċ', 'ĠĠĠĠĠ', 'Ġcluster', 'Ġ=', 'Ġself', '.', 'get', '_', 'argument', '_', 'cluster', '()', 'Ċ', 'ĠĠĠĠĠ', 'Ġrole', 'Ġ=', 'Ġself', '.', 'get', '_', 'argument', '_', 'role', '()', 'Ċ', 'ĠĠĠĠĠ', 'Ġenviron', 'Ġ=', 'Ġself', '.', 'get', '_', 'argument', '_', 'environ', '()', 'Ċ', 'ĠĠĠĠĠ', 'Ġtopology', '_', 'name', 'Ġ=', 'Ġself', '.', 'get', '_', 'argument', '_', 'topology', '()', 'Ċ', 'ĠĠĠĠĠ', 'Ġtopology', '_', 'info', 'Ġ=', 'Ġself', '.', 'tracker', '.', 'get', 'Topology', 'Info', '(', 'topology', '_', 'name', ',', 'Ġcluster', ',', 'Ġrole', ',', 'Ġenviron', ')', 'Ċ', 'ĠĠĠĠĠ', 'Ġruntime', '_', 'state', 'Ġ=', 'Ġtopology', '_', 'info', '["', 'runtime', '_', 'state', '"]', 'Ċ', 'ĠĠĠĠĠ', 'Ġruntime', '_', 'state', '["', 'topology', '_', 'version', '"]', 'Ġ=', 'Ġtopology', '_', 'info', '["', 'metadata', '"]["', 'release', '_', 'version', '"]', 'Ċ', 'ĠĠĠĠĠ', 'Ġtopology', 'Ġ=', 'Ġself', '.', 'tracker', '.', 'get', 'Topology', 'By', 'ClusterRole', 'Environ', 'AndName', '(', 'Ċ', 'ĠĠĠĠĠĠĠĠĠ', 'Ġcluster', ',', 'Ġrole', ',', 'Ġenviron', ',', 'Ġtopology', '_', 'name', ')', 'Ċ', 'ĠĠĠĠĠ', 'Ġreg', '_', 'summary', 'Ġ=', 'Ġyield', 'Ġtornado', '.', 'gen', '.', 'Task', '(', 'self', '.', 'getSt', 'mgr', 's', 'Reg', 'Summary', ',', 'Ġtopology', '.', 't', 'master', ')', 'Ċ', 'ĠĠĠĠĠ', 'Ġfor', 'Ġst', 'mgr', ',', 'Ġreg', 'Ġin', 'Ġreg', '_', 'summary', '.', 'items', '():', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġruntime', '_', 'state', '["', 'st', 'mgr', 's', '"].', 'setdefault', '(', 'st', 'mgr', ',', 'Ġ{})', '["', 'is', '_', 'registered', '"]', 'Ġ=', 'Ġreg', 'Ċ', 'ĠĠĠĠĠ', 'Ġself', '.', 'write', '_', 'success', '_', 'response', '(', 'runtime', '_', 'state', ')', 'Ċ', 'ĠĠĠ', 'Ġexcept', 'ĠException', 'Ġas', 'Ġe', ':', 'Ċ', 'ĠĠĠĠĠ', 'ĠLog', '.', 'debug', '(', 'traceback', '.', 'format', '_', 'exc', '())', 'Ċ', 'ĠĠĠĠĠ', 'Ġself', '.', 'write', '_', 'error', '_', 'response', '(', 'e', ')', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_ARG_ARG_ARG_CONSTANT_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_NAME_LOAD_IF_UNARYOP_NOT_ATTRIBUTE_NAME_LOAD_LOAD_RAISE_CALL_NAME_LOAD_BINOP_CONSTANT_MOD_NAME_LOAD_ASSIGN_NAME_STORE_CALL_NAME_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_IF_BOOLOP_OR_COMPARE_NAME_LOAD_LT_CONSTANT_COMPARE_NAME_LOAD_GT_NAME_LOAD_RAISE_CALL_NAME_LOAD_BINOP_CONSTANT_MOD_NAME_LOAD_ASSIGN_NAME_STORE_SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_ASSIGN_TUPLE_NAME_STORE_NAME_STORE_NAME_STORE_NAME_STORE_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_TUPLE_BINOP_NAME_LOAD_ADD_BINOP_NAME_LOAD_DIV_CONSTANT_BINOP_NAME_LOAD_ADD_BINOP_NAME_LOAD_DIV_CONSTANT_LOAD_RETURN_CONSTANT
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_ARG_ARG_ARG_CONSTANT_EXPR_', 'CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_NAME_LOAD_', 'IF_UNARYOP_NOT_ATTRIBUTE_NAME_LOAD_LOAD_', 'RAISE_CALL_NAME_LOAD_BINOP_CONSTANT_MOD_', 'NAME_LOAD_ASSIGN_NAME_STORE_CALL_NAME_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_', 'IF_BOOLOP_OR_COMPARE_NAME_LOAD_LT_CONSTANT_', 'COMPARE_NAME_LOAD_GT_NAME_LOAD_', 'RAISE_CALL_NAME_LOAD_BINOP_CONSTANT_MOD_NAME_LOAD_ASSIGN_NAME_STORE_', 'SUBSCRIPT_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_LOAD_', 'EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_', 'ASSIGN_TUPLE_NAME_STORE_NAME_STORE_NAME_STORE_NAME_STORE_STORE_', 'CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_', 'EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_TUPLE_', 'BINOP_NAME_LOAD_ADD_', 'BINOP_NAME_LOAD_DIV_CONSTANT_', 'BINOP_NAME_LOAD_ADD_', 'BINOP_NAME_LOAD_', 'DIV_CONSTANT_LOAD_', 'RETURN_CONSTANT']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_TRY_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_NAME_LOAD_NAME_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_SUBSCRIPT_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_CONSTANT_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_NAME_LOAD_NAME_LOAD_NAME_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_YIELD_CALL_ATTRIBUTE_ATTRIBUTE_NAME_LOAD_LOAD_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_ATTRIBUTE_NAME_LOAD_LOAD_FOR_TUPLE_NAME_STORE_NAME_STORE_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_SUBSCRIPT_CALL_ATTRIBUTE_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_LOAD_NAME_LOAD_DICT_CONSTANT_STORE_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_EXCEPTHANDLER_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CALL_ATTRIBUTE_NAME_LOAD_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def get(self, pk, cascadeFetch=False):
#
# 		conn = self._get_connection()
# 		key = self._get_key_for_id(pk)
# 		res = conn.hgetall(key)
# 		if type(res) != dict or not len(res.keys()):
# 			return None
# 		res['_id'] = pk
#
# 		ret = self._redisResultToObj(res)
# 		if cascadeFetch is True:
# 			self._doCascadeFetch(ret)
# 		return ret
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġget', '(', 'self', ',', 'Ġpk', ',', 'Ġcascade', 'Fetch', '=', 'False', '):', 'Ċ', 'ĉĉĊ', 'ĉ', 'ĉ', 'conn', 'Ġ=', 'Ġself', '._', 'get', '_', 'connection', '()', 'Ċ', 'ĉ', 'ĉ', 'key', 'Ġ=', 'Ġself', '._', 'get', '_', 'key', '_', 'for', '_', 'id', '(', 'pk', ')', 'Ċ', 'ĉ', 'ĉ', 'res', 'Ġ=', 'Ġconn', '.', 'hget', 'all', '(', 'key', ')', 'Ċ', 'ĉ', 'ĉ', 'if', 'Ġtype', '(', 'res', ')', 'Ġ!=', 'Ġdict', 'Ġor', 'Ġnot', 'Ġlen', '(', 'res', '.', 'keys', '()):', 'Ċ', 'ĉĉ', 'ĉ', 'return', 'ĠNone', 'Ċ', 'ĉ', 'ĉ', 'res', "['_", 'id', "']", 'Ġ=', 'Ġpk', 'Ċ', 'Ċ', 'ĉ', 'ĉ', 'ret', 'Ġ=', 'Ġself', '._', 'redis', 'Result', 'To', 'Obj', '(', 'res', ')', 'Ċ', 'ĉ', 'ĉ', 'if', 'Ġcascade', 'Fetch', 'Ġis', 'ĠTrue', ':', 'Ċ', 'ĉĉ', 'ĉ', 'self', '._', 'do', 'Cascade', 'Fetch', '(', 'ret', ')', 'Ċ', 'ĉ', 'ĉ', 'return', 'Ġret', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_LIST_SUBSCRIPT_CALL_NAME_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_CONSTANT_LOAD_SUBSCRIPT_CALL_NAME_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_CONSTANT_LOAD_SUBSCRIPT_CALL_NAME_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_CONSTANT_LOAD_SUBSCRIPT_CALL_NAME_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_CONSTANT_LOAD_SUBSCRIPT_CALL_NAME_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_CONSTANT_LOAD_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_CONSTANT_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_LOAD_RETURN_NAME_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_', 'LIST_', 'SUBSCRIPT_', 'CALL_NAME_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_', 'CONSTANT_LOAD_', 'SUBSCRIPT_', 'CALL_NAME_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_', 'CONSTANT_LOAD_', 'SUBSCRIPT_', 'CALL_NAME_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_', 'CONSTANT_LOAD_', 'SUBSCRIPT_', 'CALL_NAME_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_', 'CONSTANT_LOAD_', 'SUBSCRIPT_', 'CALL_NAME_LOAD_SUBSCRIPT_NAME_LOAD_CONSTANT_LOAD_', 'CONSTANT_LOAD_LOAD_ASSIGN_NAME_STORE_', 'CALL_ATTRIBUTE_CONSTANT_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_', 'CALL_ATTRIBUTE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_LOAD_', 'RETURN_NAME_LOAD']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_ARG_CONSTANT_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_IF_BOOLOP_OR_COMPARE_CALL_NAME_LOAD_NAME_LOAD_NOTEQ_NAME_LOAD_UNARYOP_NOT_CALL_NAME_LOAD_CALL_ATTRIBUTE_NAME_LOAD_LOAD_RETURN_CONSTANT_ASSIGN_SUBSCRIPT_NAME_LOAD_CONSTANT_STORE_NAME_LOAD_ASSIGN_NAME_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_IF_COMPARE_NAME_LOAD_IS_CONSTANT_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_NAME_LOAD_RETURN_NAME_LOAD
# For label NOT RELATED, model predicted RELATED.
#
# Source:_____
# def dict_remove_value(d, v):
#
#     dd = dict()
#     for key, value in d.items():
#         if not value == v:
#             if isinstance(value, dict):
#                 dd[key] = dict_remove_value(value, v)
#             elif isinstance(value, list):
#                 dd[key] = [dict_remove_value(i, v) for i in value]
#             else:
#                 dd[key] = value
#     return dd
#
# Source Tokenization:_____
# ['<s>', 'def', 'Ġdict', '_', 'remove', '_', 'value', '(', 'd', ',', 'Ġv', '):', 'Ċ', 'ĠĠĠĠĊ', 'ĠĠĠ', 'Ġdd', 'Ġ=', 'Ġdict', '()', 'Ċ', 'ĠĠĠ', 'Ġfor', 'Ġkey', ',', 'Ġvalue', 'Ġin', 'Ġd', '.', 'items', '():', 'Ċ', 'ĠĠĠĠĠĠĠ', 'Ġif', 'Ġnot', 'Ġvalue', 'Ġ==', 'Ġv', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġif', 'Ġisinstance', '(', 'value', ',', 'Ġdict', '):', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġdd', '[', 'key', ']', 'Ġ=', 'Ġdict', '_', 'remove', '_', 'value', '(', 'value', ',', 'Ġv', ')', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġelif', 'Ġisinstance', '(', 'value', ',', 'Ġlist', '):', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġdd', '[', 'key', ']', 'Ġ=', 'Ġ[', 'dict', '_', 'remove', '_', 'value', '(', 'i', ',', 'Ġv', ')', 'Ġfor', 'Ġi', 'Ġin', 'Ġvalue', ']', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠ', 'Ġelse', ':', 'Ċ', 'ĠĠĠĠĠĠĠĠĠĠĠĠĠĠĠ', 'Ġdd', '[', 'key', ']', 'Ġ=', 'Ġvalue', 'Ċ', 'ĠĠĠ', 'Ġreturn', 'Ġdd', '</s>']
#
# AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_NAME_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_CALL_NAME_LOAD_KEYWORD_NAME_LOAD_KEYWORD_NAME_LOAD_ASSIGN_NAME_STORE_CONSTANT_TRY_IF_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_KEYWORD_CONSTANT_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_KEYWORD_CONSTANT_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_KEYWORD_CONSTANT_EXCEPTHANDLER_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_ASSIGN_NAME_STORE_NAME_LOAD_IF_NAME_LOAD_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CALL_ATTRIBUTE_CONSTANT_LOAD_NAME_LOAD
#
# AST Tokenization:_____
# ['MODULE_FUNCTIONDEF_ARGUMENTS_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_', 'CALL_NAME_LOAD_NAME_LOAD_ASSIGN_NAME_STORE_CALL_NAME_LOAD_', 'KEYWORD_NAME_LOAD_KEYWORD_', 'NAME_LOAD_ASSIGN_NAME_STORE_CONSTANT_', 'TRY_', 'IF_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_', 'KEYWORD_CONSTANT_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'KEYWORD_CONSTANT_EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_', 'KEYWORD_CONSTANT_EXCEPTHANDLER_NAME_LOAD_', 'EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CONSTANT_ASSIGN_NAME_STORE_', 'NAME_LOAD_IF_NAME_LOAD_', 'EXPR_CALL_ATTRIBUTE_NAME_LOAD_LOAD_CALL_ATTRIBUTE_CONSTANT_LOAD_NAME_LOAD']
#
# Correct AST:_____
# MODULE_FUNCTIONDEF_ARGUMENTS_ARG_ARG_EXPR_CONSTANT_ASSIGN_NAME_STORE_CALL_NAME_LOAD_FOR_TUPLE_NAME_STORE_NAME_STORE_STORE_CALL_ATTRIBUTE_NAME_LOAD_LOAD_IF_UNARYOP_NOT_COMPARE_NAME_LOAD_EQ_NAME_LOAD_IF_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_NAME_LOAD_STORE_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_IF_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_NAME_LOAD_STORE_LISTCOMP_CALL_NAME_LOAD_NAME_LOAD_NAME_LOAD_COMPREHENSION_NAME_STORE_NAME_LOAD_ASSIGN_SUBSCRIPT_NAME_LOAD_NAME_LOAD_STORE_NAME_LOAD_RETURN_NAME_LOAD

# %%
# get the average length of errors

distribution_ast = [0 for _ in range(189+1)]

sum_asts = 0
sum_srcs = 0
max_ast  = 0

for _ in errors:
    max_ast = max(max_ast, len(_['ast_tokenization']))
    sum_asts += len(_['ast_tokenization'])
    sum_srcs += len(_['src_tokenization'])
    distribution_ast[int(len(_['ast_tokenization']))] += 1

print(f'ASTs: {sum_asts / len(errors):.1f}')
print(f'SRCs: {sum_srcs / len(errors):.1f}')
# Out:
# ASTs: 10.9
# SRCs: 118.7

# %%
import matplotlib.pyplot as plt

plt.bar(distribution_ast, list(range(len(distribution_ast))), color='black'); None
